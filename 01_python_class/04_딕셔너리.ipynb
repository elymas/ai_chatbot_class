# %% [markdown]
# # 4.딕셔너리
# 딕셔너리도 여러개의 값을 담는 변수입니다.

# %% [markdown]
# ## 4-1.딕셔너리 형식
# <pre>
# * 형식 :
#   딕셔너리이름 = {'key값1':'value값1', 'key값2':'value값2', 'key값3':'value값3', ...}
#   딕셔너리이름 = {}
#
#
# * 리스트 이름으로 안되는 것들 :
#   - if, def, class, while, for, else 등의 예약어
#   - 숫자로 시작하는 것
#   ex) 1a, 3name, ...
#
#
# * 딕셔너리의 특징
#   1.key값과 value값의 쌍 형태
#   2.인덱스(순번)을 가지지 않음
#   3.인덱스 대신 key값으로 value를 불러옴
#   4.수정 가능

# %% [markdown]
# ## 4-2.딕셔너리 사용법
# <pre>
# 딕셔너리를 사용하면 이런 것을 할 수 있습니다.
# 가령
# 방탄 소년단 멤버와 그들의 나이가 있을 수 있지요.
# 이를 한 번에 담아 둘 수 없을까요?
# 이 때 유용한 것이 딕셔너리 입니다.

# %% [markdown]
# #### 딕셔너리 만들기

# %%
# 빈 딕셔너리
dict1 = {}

# %%
colors = {'red':3, 'blue':2, 'yellow':7}

# %%
# BTS의 이름을 key로 나이를 value로 만든 딕셔너리
a = {'진':'22', '슈가':'5','제이홉':'66'}

# %% [markdown]
# #### key값으로 value 가져오기
# <pre>
# *사용법:
# 딕셔너리명[key값]

# %%
# key값 '진'으로 value값 가져오기
print(a['진'])
# Out:
# 22

# %%
# key값 '슈가', '제이홉'으로 value값 가져오기
print(a['슈가'],a['제이홉'])
# Out:
# 5 66

# %%
a = {'name':'John', 'loc':'LA', 'phone':"01023456789"}
print(a['name'])
print(a['loc'])
print(a['phone'])
# Out:
# John
# LA
# 01023456789

# %% [markdown]
# ### value 값으로 리스트 넣기/ value 값 가져오기

# %%
a = ['철수', '민수', '민지']
b = ['서울', '부산', '대전']
c = ['01022223333', '01033334444', '01044445555']

contact = {'이름':a, '지역':b, '전화번호':c}
print(contact)
print(contact['이름'])
print(contact['지역'])
print(contact['전화번호'])
# Out:
# {'이름': ['철수', '민수', '민지'], '지역': ['서울', '부산', '대전'], '전화번호': ['01022223333', '01033334444', '01044445555']}
# ['철수', '민수', '민지']
# ['서울', '부산', '대전']
# ['01022223333', '01033334444', '01044445555']

# %% [markdown]
# ### 딕셔너리 주의 사항
# * key값은 동일하면 안됨
#
# * key값으로 리스트가 올 수 없음.

# %%
a = {'이름':'kim', '이름':'lee'}

# %%
print(a['이름'])
# Out:
# lee

# %% [markdown]
# ### key값들을 리스트로 만들기(keys() 함수)
# key값들만 모아서 리스트처럼 만들 수 있습니다.
#
# <pre>
# *사용법:
# 딕셔너리명.keys()

# %%
a = {'이름':'kim', '나이':24, '지역':'서울'}

# %%
a.keys()
print(a.keys())
# Out:
# dict_keys(['이름', '나이', '지역'])

# %% [markdown]
# 리스트 같지만 리스트의 함수들인 append, insert, remove 등은 사용할 수 없음.

# %% [markdown]
# dict_keys를 리스트로 바꾸려면
#
# list를 만들어주는 list()함수를 사용하면 됩니다.
#
# 리스트명 = list(값)

# %%
a = {'이름':'kim', '나이':24, '지역':'서울'}

# %%
# list함수로 리스트로 만들어 list1에 저장
list1 = list(a.keys())
print(list1)
# Out:
# ['이름', '나이', '지역']

# %%
list1.append('성별')
print(list1)
# Out:
# ['이름', '나이', '지역', '성별']

# %% [markdown]
# 이제 append, insert, remove 등의 함수를 사용할 수 있습니다.

# %% [markdown]
# ### value 값들을 리스트로 만들기(values() 함수)
# keys() 함수처럼 사용하면 됩니다.
#
# values()를 사용합시다.

# %%
a = {'이름':'kim', '나이':24, '지역':'서울'}

# %%
print(a.values())
# Out:
# dict_values(['kim', 24, '서울'])

# %% [markdown]
# 리스트 같지만 리스트 아닌 이것을
#
# list() 함수를 이용해서 바꿔줍시다.

# %%
a = {'이름':'kim', '나이':24, '지역':'서울'}

# %%
# list() 함수를 적용하여 list로 만들어 list2라는 이름으로 저장
list2 = list(a.values())
print(list2)
# Out:
# ['kim', 24, '서울']

# %%
list2.insert(2, "남성")
print(list2)
# Out:
# ['kim', 24, '남성', '서울']

# %% [markdown]
# ### key, value 쌍 얻기(items() 함수)
# <pre>
# *사용법:
# 딕셔너리명.items()

# %%
a = {'이름':'kim', '나이':24, '지역':'서울'}

# %%
print(a.items())
# Out:
# dict_items([('이름', 'kim'), ('나이', 24), ('지역', '서울')])

# %% [markdown]
# 마찬가지로 list()함수를 이용해서 리스트로 만들 수 있습니다.

# %%
a = {'이름':'kim', '나이':24, '지역':'서울'}

# %%
list3 = list(a.items())
print(list3)
# Out:
# [('이름', 'kim'), ('나이', 24), ('지역', '서울')]

# %% [markdown]
# ### key, value쌍 모두 지우기(clear() 함수)
# <pre>
# *사용법:
# 딕셔너리명.clear()

# %%
a = {'이름':'kim', '나이':24, '지역':'서울'}

# %%
print(a.clear())
# Out:
# None

# %%
print(a)
# Out:
# {}

# %% [markdown]
# ### 해당 key가 딕셔너리 안에 있는지 조사하기
# <pre>
# * 사용법:
# key값 in 딕셔너리

# %%
z = {'name':1, 'loc':2, 'age':3}

# %%
'name' in z
# Out:
# True

# %%
'gender' in z
# Out:
# False

# %% [markdown]
# True 는 있음
#
# False는 없음
