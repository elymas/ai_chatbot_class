# %% [markdown]
# # Matplotlib
#
# 파이썬 데이터 분석의 3대 라이브러리:
# * Numpy : 배열, 행열을 다룸
# * Pandas : 엑셀와 같은 데이터프레임을 다룸
# * Matplotlib : 시각화

# %%
# 매직커맨드 : 쥬피터노트북에서 그래프 제대로 확인시 넣어줌
# matplotlib inline을 쓰면 
# 주피터노트북에서 매번 plt.show()을 실행해 주지 않아도 된다. 
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# 2.Plot의 종류
## line plot, bar plot, histogram, scatterplot

# %%
# Line plot 그리기
# 직선 그래프
# Series를 통한 line plot 그리기
s = pd.Series(np.random.rand(10), index=np.arange(0, 100, 10))
s
# Out:
# 0     0.881971
# 10    0.824963
# 20    0.638082
# 30    0.144573
# 40    0.453780
# 50    0.983499
# 60    0.105194
# 70    0.023158
# 80    0.183573
# 90    0.441965
# dtype: float64

# %%
# 위에서 정의한 s라는 시리즈에 대해서 line plot을 그리고 싶다면?
s.plot()

# %%
# s라는 Series에서의 index와 value를 통해 그래프가 그려졌다.

# %%
# DataFrame을 통한 line plot 그리기
df = pd.DataFrame(np.random.rand(10, 4), columns=['A','B','C','D'], index=np.arange(0,100,10))
df
# Out:
#            A         B         C         D
# 0   0.318393  0.295453  0.278394  0.587074
# 10  0.046175  0.664415  0.466221  0.589713
# 20  0.564774  0.680747  0.053737  0.688818
# 30  0.026354  0.823622  0.067161  0.305973
# 40  0.643033  0.330161  0.622588  0.420114
# 50  0.748544  0.106422  0.839892  0.522326
# 60  0.133400  0.375027  0.707757  0.987191
# 70  0.371635  0.751170  0.543563  0.039184
# 80  0.958262  0.029202  0.819592  0.002512
# 90  0.173306  0.828971  0.945494  0.118946

# %%
df.plot()

# %%
df['B'].plot()

# %%
df[['B', 'D']].plot()

# %%
# Barplot 그리기
s2 = pd.Series(np.random.rand(16), index=list('abcdefghijklmnop'))
s2
# Out:
# a    0.972279
# b    0.523447
# c    0.328321
# d    0.163565
# e    0.851889
# f    0.224717
# g    0.473077
# h    0.817723
# i    0.686683
# j    0.804541
# k    0.872015
# l    0.806153
# m    0.085124
# n    0.592768
# o    0.992567
# p    0.768214
# dtype: float64

# %%
s2.plot(kind='bar')

# %%
# 가로방향의 bar plot 그리기
s2.plot(kind='barh')

# %%
df2 = pd.DataFrame(np.random.rand(6,4), index=['one', 'two', 'three', 'four', 'five', 'six'], columns=(['A', 'B', 'C', 'D']))
df2
# Out:
#               A         B         C         D
# one    0.301563  0.034420  0.393944  0.826431
# two    0.505944  0.565569  0.987096  0.630663
# three  0.204856  0.371002  0.991086  0.399075
# four   0.537260  0.051248  0.992026  0.239570
# five   0.792430  0.031077  0.240554  0.663844
# six    0.686791  0.733702  0.275602  0.268295

# %%
df3 = pd.DataFrame(np.random.rand(6,4), index=['one', 'two', 'three', 'four', 'five', 'six'], columns=pd.Index(['A', 'B', 'C', 'D']))
df3
# Out:
#               A         B         C         D
# one    0.274100  0.018168  0.930074  0.636777
# two    0.953707  0.688630  0.664282  0.347723
# three  0.947054  0.503076  0.494523  0.610220
# four   0.039638  0.806966  0.123902  0.309821
# five   0.015916  0.276430  0.249766  0.637193
# six    0.045873  0.894070  0.004355  0.782131

# %%
df2.plot(kind='bar')

# %%
df2.plot(kind='barh')

# %%
df2.plot(kind='bar', stacked=True)

# %%
df2.plot(kind='barh', stacked=True)

# %%
# 위와 같이 stacked 속성을 True로 설정하면, 하나의 인덱스에 대한
# 각 열의 값을 한 줄로 쌓아서 나타내준다.

# %%
# Histogram 그리기
# histogram은 index가 필요 없다.
# 기대값이 0이고 표준편차가 1인 200개의 랜덤 값
s3 = pd.Series(np.random.normal(0,1, size=200))

# %%
s4 = pd.Series(np.random.randn(200))

# %%
s3.hist()

# %%
s4.hist()

# %%
# x축의 구간 개수를 bin이라고 한다.
# 이를 직접 설정할 수도 있다.

# %%
s3.hist(bins=100)  # default 값은 10

# %%
# normed 속성을 True로 설정하면,
# 각 bin(구간)에 속하는 개수를 전체 개수로 나눈 비율,
# 즉 정규화 한 값을 bar의 높이로 사용하게 된다.
s3.hist(bins=100, normed=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
# 산점도(scatter plot)그리기
# 산점도의 경우에는
# 서로 다른 두 개의 독립변수에 대해
# 두 변수가 어떤 관계가 있는지
# 살펴보기 위해 사용

# %%
# 어레이들을 합친다. 
# axis=0 : 하나의 행으로 합치기
# axis=1 : 열로 합치기
x1 = np.random.normal(1,1,size=(100,1))
x2 = np.random.normal(-2,4,size=(100,1))

X = np.concatenate((x1, x2), axis=1)
X
# Out:
# array([[ 2.62116398e+00, -4.62671411e+00],
#        [ 1.67574932e+00, -4.19091893e+00],
#        [ 1.44122464e+00,  2.02117328e+00],
#        [ 2.60843087e+00,  3.18713604e+00],
#        [ 4.62505614e-01, -4.58128165e+00],
#        [ 1.28097798e+00, -7.96707132e-01],
#        [-4.27151406e-01,  1.82387987e+00],
#        [ 2.68188589e+00, -4.05727520e+00],
#        [-5.76496550e-01, -3.73964080e+00],
#        [ 1.17268663e+00, -8.34852562e+00],
#        [ 1.82707721e-02, -6.09309102e+00],
#        [ 1.85192823e+00, -3.32954428e+00],
#        [ 1.92787477e+00, -4.63977622e+00],
#        [ 7.82506613e-01, -5.92494344e-03],
#        [ 1.26174087e+00, -3.09994713e+00],
#        [ 6.25914075e-01,  5.38424052e+00],
#        [ 1.36274692e+00, -4.70961794e+00],
#        [ 9.04898314e-01, -4.11907243e+00],
#        [ 1.40566360e+00, -2.34033363e+00],
#        [ 1.17466911e+00, -3.17050102e+00],
#        [ 4.05927489e-01,  5.08147772e+00],
#        [ 9.52901268e-01, -4.20104751e+00],
#        [ 3.12971436e+00, -1.70321144e-01],
#        [ 3.04368930e+00, -5.15042303e+00],
#        [ 6.69170868e-01, -6.99760850e+00],
#        [-4.52310355e-02, -5.00012427e+00],
#        [ 1.57891376e+00, -4.19006858e+00],
#        [ 1.55009663e+00, -3.93828310e+00],
#        [ 1.06732688e-02, -2.03185487e+00],
#        [ 1.04475764e-01, -2.05455437e+00],
#        [ 1.92984297e-01,  1.06445835e+00],
#        [ 1.67841337e+00,  4.75272110e+00],
#        [ 1.20876633e+00, -6.46960739e+00],
#        [ 1.62184937e+00, -7.16576789e+00],
#        [-1.42614864e-01, -3.36776041e-01],
#        [ 1.83258826e+00,  1.71578954e+00],
#        [ 4.66341170e-01, -1.34445521e+00],
#        [ 2.16115296e+00, -2.56291449e+00],
#        [-4.94339625e-01, -9.77444379e+00],
#        [ 5.76509317e-01,  4.18303947e+00],
#        [ 8.55159559e-01,  4.84169783e+00],
#        [ 1.34739004e+00, -2.08174579e+00],
#        [-2.47198098e-01, -4.43111921e+00],
#        [ 8.59502439e-01, -9.94032017e-01],
#        [-2.20779769e-02, -3.14389014e-01],
#        [ 2.10915790e-01, -2.70926332e+00],
#        [ 5.16989610e-01,  5.61720547e+00],
#        [ 4.15373750e-01, -3.66941655e+00],
#        [ 2.91956630e-01,  3.32532638e+00],
#        [ 1.96108783e-01, -2.19465568e+00],
#        [ 3.97342505e-01,  1.96950393e+00],
#        [ 7.94527910e-01, -2.99928561e+00],
#        [ 6.73447188e-01, -1.24133009e+00],
#        [ 2.26208034e+00, -5.31671367e+00],
#        [ 2.15842671e+00, -2.82047703e-01],
#        [-1.65584570e-01,  8.81903333e-01],
#        [ 6.46922965e-01,  4.08407754e+00],
#        [-1.40785541e-01, -3.80374083e+00],
#        [ 1.47085731e+00, -3.93057812e-01],
#        [ 7.60820118e-01,  1.25995766e+00],
#        [ 5.61833886e-01, -4.72096507e-01],
#        [ 1.17280881e+00, -2.58723531e+00],
#        [ 1.34346140e+00, -3.15406208e+00],
#        [ 1.14268845e+00,  4.20283513e-01],
#        [ 7.26309429e-01, -4.14243819e+00],
#        [ 3.27533223e+00, -5.32295524e+00],
#        [ 2.49888218e+00,  1.25977325e+00],
#        [ 4.69498543e-01, -1.42088431e+00],
#        [ 1.53291175e+00,  1.59146261e+00],
#        [-6.56833666e-02, -8.37933249e-01],
#        [ 1.65805708e+00,  3.95219819e-01],
#        [-8.26077204e-01, -6.31329957e+00],
#        [ 1.91563346e+00, -3.92933847e+00],
#        [ 3.32745321e+00, -9.92438828e-01],
#        [ 1.53253541e+00, -3.08210439e+00],
#        [ 1.38165192e+00, -3.52640736e+00],
#        [ 1.29947390e+00, -4.38130140e+00],
#        [ 9.29030452e-01, -2.74402812e+00],
#        [-2.49872964e-01, -8.32336362e-01],
#        [ 1.92647282e+00, -5.72354640e+00],
#        [ 1.50716590e+00, -5.55328111e+00],
#        [ 1.95448322e+00,  6.27959729e-01],
#        [ 2.00253084e-01, -8.11820228e+00],
#        [ 2.93724788e+00,  1.67131379e+00],
#        [ 2.59159459e-01,  1.80772507e+00],
#        [ 1.53873803e+00, -1.09868166e+01],
#        [ 2.08567690e-01, -1.36895961e+00],
#        [ 1.79680418e+00, -6.68099656e+00],
#        [ 4.52817606e-01, -1.20064167e+00],
#        [ 1.43601251e+00, -7.41973507e+00],
#        [ 9.40971029e-01, -1.25965691e+00],
#        [ 1.45661977e+00, -5.08603368e+00],
#        [ 6.75486897e-01,  3.35354242e+00],
#        [ 2.51132684e+00,  3.08963648e+00],
#        [-1.93725470e+00, -4.78510379e+00],
#        [ 5.57312404e-02, -9.17457662e+00],
#        [ 1.40827212e+00,  2.80769687e+00],
#        [ 5.44408738e-01, -3.54966978e-01],
#        [ 1.82014462e+00, -3.65786137e+00],
#        [ 1.13801904e+00, -5.82882277e+00]])

# %%
Y = np.concatenate((x1, x2), axis=0)
Y
# Out:
# array([[ 2.62116398e+00],
#        [ 1.67574932e+00],
#        [ 1.44122464e+00],
#        [ 2.60843087e+00],
#        [ 4.62505614e-01],
#        [ 1.28097798e+00],
#        [-4.27151406e-01],
#        [ 2.68188589e+00],
#        [-5.76496550e-01],
#        [ 1.17268663e+00],
#        [ 1.82707721e-02],
#        [ 1.85192823e+00],
#        [ 1.92787477e+00],
#        [ 7.82506613e-01],
#        [ 1.26174087e+00],
#        [ 6.25914075e-01],
#        [ 1.36274692e+00],
#        [ 9.04898314e-01],
#        [ 1.40566360e+00],
#        [ 1.17466911e+00],
#        [ 4.05927489e-01],
#        [ 9.52901268e-01],
#        [ 3.12971436e+00],
#        [ 3.04368930e+00],
#        [ 6.69170868e-01],
#        [-4.52310355e-02],
#        [ 1.57891376e+00],
#        [ 1.55009663e+00],
#        [ 1.06732688e-02],
#        [ 1.04475764e-01],
#        [ 1.92984297e-01],
#        [ 1.67841337e+00],
#        [ 1.20876633e+00],
#        [ 1.62184937e+00],
#        [-1.42614864e-01],
#        [ 1.83258826e+00],
#        [ 4.66341170e-01],
#        [ 2.16115296e+00],
#        [-4.94339625e-01],
#        [ 5.76509317e-01],
#        [ 8.55159559e-01],
#        [ 1.34739004e+00],
#        [-2.47198098e-01],
#        [ 8.59502439e-01],
#        [-2.20779769e-02],
#        [ 2.10915790e-01],
#        [ 5.16989610e-01],
#        [ 4.15373750e-01],
#        [ 2.91956630e-01],
#        [ 1.96108783e-01],
#        [ 3.97342505e-01],
#        [ 7.94527910e-01],
#        [ 6.73447188e-01],
#        [ 2.26208034e+00],
#        [ 2.15842671e+00],
#        [-1.65584570e-01],
#        [ 6.46922965e-01],
#        [-1.40785541e-01],
#        [ 1.47085731e+00],
#        [ 7.60820118e-01],
#        [ 5.61833886e-01],
#        [ 1.17280881e+00],
#        [ 1.34346140e+00],
#        [ 1.14268845e+00],
#        [ 7.26309429e-01],
#        [ 3.27533223e+00],
#        [ 2.49888218e+00],
#        [ 4.69498543e-01],
#        [ 1.53291175e+00],
#        [-6.56833666e-02],
#        [ 1.65805708e+00],
#        [-8.26077204e-01],
#        [ 1.91563346e+00],
#        [ 3.32745321e+00],
#        [ 1.53253541e+00],
#        [ 1.38165192e+00],
#        [ 1.29947390e+00],
#        [ 9.29030452e-01],
#        [-2.49872964e-01],
#        [ 1.92647282e+00],
#        [ 1.50716590e+00],
#        [ 1.95448322e+00],
#        [ 2.00253084e-01],
#        [ 2.93724788e+00],
#        [ 2.59159459e-01],
#        [ 1.53873803e+00],
#        [ 2.08567690e-01],
#        [ 1.79680418e+00],
#        [ 4.52817606e-01],
#        [ 1.43601251e+00],
#        [ 9.40971029e-01],
#        [ 1.45661977e+00],
#        [ 6.75486897e-01],
#        [ 2.51132684e+00],
#        [-1.93725470e+00],
#        [ 5.57312404e-02],
#        [ 1.40827212e+00],
#        [ 5.44408738e-01],
#        [ 1.82014462e+00],
#        [ 1.13801904e+00],
#        [-4.62671411e+00],
#        [-4.19091893e+00],
#        [ 2.02117328e+00],
#        [ 3.18713604e+00],
#        [-4.58128165e+00],
#        [-7.96707132e-01],
#        [ 1.82387987e+00],
#        [-4.05727520e+00],
#        [-3.73964080e+00],
#        [-8.34852562e+00],
#        [-6.09309102e+00],
#        [-3.32954428e+00],
#        [-4.63977622e+00],
#        [-5.92494344e-03],
#        [-3.09994713e+00],
#        [ 5.38424052e+00],
#        [-4.70961794e+00],
#        [-4.11907243e+00],
#        [-2.34033363e+00],
#        [-3.17050102e+00],
#        [ 5.08147772e+00],
#        [-4.20104751e+00],
#        [-1.70321144e-01],
#        [-5.15042303e+00],
#        [-6.99760850e+00],
#        [-5.00012427e+00],
#        [-4.19006858e+00],
#        [-3.93828310e+00],
#        [-2.03185487e+00],
#        [-2.05455437e+00],
#        [ 1.06445835e+00],
#        [ 4.75272110e+00],
#        [-6.46960739e+00],
#        [-7.16576789e+00],
#        [-3.36776041e-01],
#        [ 1.71578954e+00],
#        [-1.34445521e+00],
#        [-2.56291449e+00],
#        [-9.77444379e+00],
#        [ 4.18303947e+00],
#        [ 4.84169783e+00],
#        [-2.08174579e+00],
#        [-4.43111921e+00],
#        [-9.94032017e-01],
#        [-3.14389014e-01],
#        [-2.70926332e+00],
#        [ 5.61720547e+00],
#        [-3.66941655e+00],
#        [ 3.32532638e+00],
#        [-2.19465568e+00],
#        [ 1.96950393e+00],
#        [-2.99928561e+00],
#        [-1.24133009e+00],
#        [-5.31671367e+00],
#        [-2.82047703e-01],
#        [ 8.81903333e-01],
#        [ 4.08407754e+00],
#        [-3.80374083e+00],
#        [-3.93057812e-01],
#        [ 1.25995766e+00],
#        [-4.72096507e-01],
#        [-2.58723531e+00],
#        [-3.15406208e+00],
#        [ 4.20283513e-01],
#        [-4.14243819e+00],
#        [-5.32295524e+00],
#        [ 1.25977325e+00],
#        [-1.42088431e+00],
#        [ 1.59146261e+00],
#        [-8.37933249e-01],
#        [ 3.95219819e-01],
#        [-6.31329957e+00],
#        [-3.92933847e+00],
#        [-9.92438828e-01],
#        [-3.08210439e+00],
#        [-3.52640736e+00],
#        [-4.38130140e+00],
#        [-2.74402812e+00],
#        [-8.32336362e-01],
#        [-5.72354640e+00],
#        [-5.55328111e+00],
#        [ 6.27959729e-01],
#        [-8.11820228e+00],
#        [ 1.67131379e+00],
#        [ 1.80772507e+00],
#        [-1.09868166e+01],
#        [-1.36895961e+00],
#        [-6.68099656e+00],
#        [-1.20064167e+00],
#        [-7.41973507e+00],
#        [-1.25965691e+00],
#        [-5.08603368e+00],
#        [ 3.35354242e+00],
#        [ 3.08963648e+00],
#        [-4.78510379e+00],
#        [-9.17457662e+00],
#        [ 2.80769687e+00],
#        [-3.54966978e-01],
#        [-3.65786137e+00],
#        [-5.82882277e+00]])

# %%
df3 = pd.DataFrame(X, columns=['x1', 'x2'])
df3
# Out:
#           x1         x2
# 0   2.621164  -4.626714
# 1   1.675749  -4.190919
# 2   1.441225   2.021173
# 3   2.608431   3.187136
# 4   0.462506  -4.581282
# 5   1.280978  -0.796707
# 6  -0.427151   1.823880
# 7   2.681886  -4.057275
# 8  -0.576497  -3.739641
# 9   1.172687  -8.348526
# 10  0.018271  -6.093091
# 11  1.851928  -3.329544
# 12  1.927875  -4.639776
# 13  0.782507  -0.005925
# 14  1.261741  -3.099947
# 15  0.625914   5.384241
# 16  1.362747  -4.709618
# 17  0.904898  -4.119072
# 18  1.405664  -2.340334
# 19  1.174669  -3.170501
# 20  0.405927   5.081478
# 21  0.952901  -4.201048
# 22  3.129714  -0.170321
# 23  3.043689  -5.150423
# 24  0.669171  -6.997608
# 25 -0.045231  -5.000124
# 26  1.578914  -4.190069
# 27  1.550097  -3.938283
# 28  0.010673  -2.031855
# 29  0.104476  -2.054554
# ..       ...        ...
# 70  1.658057   0.395220
# 71 -0.826077  -6.313300
# 72  1.915633  -3.929338
# 73  3.327453  -0.992439
# 74  1.532535  -3.082104
# 75  1.381652  -3.526407
# 76  1.299474  -4.381301
# 77  0.929030  -2.744028
# 78 -0.249873  -0.832336
# 79  1.926473  -5.723546
# 80  1.507166  -5.553281
# 81  1.954483   0.627960
# 82  0.200253  -8.118202
# 83  2.937248   1.671314
# 84  0.259159   1.807725
# 85  1.538738 -10.986817
# 86  0.208568  -1.368960
# 87  1.796804  -6.680997
# 88  0.452818  -1.200642
# 89  1.436013  -7.419735
# 90  0.940971  -1.259657
# 91  1.456620  -5.086034
# 92  0.675487   3.353542
# 93  2.511327   3.089636
# 94 -1.937255  -4.785104
# 95  0.055731  -9.174577
# 96  1.408272   2.807697
# 97  0.544409  -0.354967
# 98  1.820145  -3.657861
# 99  1.138019  -5.828823
#
# [100 rows x 2 columns]

# %%
# x1이 x축, x2가 y축
plt.scatter(df3['x1'], df3['x2'])

# %%
x1 = np.arange(0,100,1).reshape(100,1)
x2 = np.arange(0,200,2).reshape(100,1)

X = np.concatenate((x1, x2), axis=1)

df4 = pd.DataFrame(X, columns=['x1','x2'])
df4
# Out:
#     x1   x2
# 0    0    0
# 1    1    2
# 2    2    4
# 3    3    6
# 4    4    8
# 5    5   10
# 6    6   12
# 7    7   14
# 8    8   16
# 9    9   18
# 10  10   20
# 11  11   22
# 12  12   24
# 13  13   26
# 14  14   28
# 15  15   30
# 16  16   32
# 17  17   34
# 18  18   36
# 19  19   38
# 20  20   40
# 21  21   42
# 22  22   44
# 23  23   46
# 24  24   48
# 25  25   50
# 26  26   52
# 27  27   54
# 28  28   56
# 29  29   58
# ..  ..  ...
# 70  70  140
# 71  71  142
# 72  72  144
# 73  73  146
# 74  74  148
# 75  75  150
# 76  76  152
# 77  77  154
# 78  78  156
# 79  79  158
# 80  80  160
# 81  81  162
# 82  82  164
# 83  83  166
# 84  84  168
# 85  85  170
# 86  86  172
# 87  87  174
# 88  88  176
# 89  89  178
# 90  90  180
# 91  91  182
# 92  92  184
# 93  93  186
# 94  94  188
# 95  95  190
# 96  96  192
# 97  97  194
# 98  98  196
# 99  99  198
#
# [100 rows x 2 columns]

# %%
plt.scatter(df4['x1'], df4['x2'])

# %%
x1 = np.arange(0,100,1).reshape(1,100)
x2 = np.arange(0,200,2).reshape(1,100)

X = np.concatenate((x1, x2), axis=0)

df4 = pd.DataFrame(X, index=['x1','x2'])
df4
# Out:
#     0   1   2   3   4   5   6   7   ...   92   93   94   95   96   97   98   99
# x1   0   1   2   3   4   5   6   7  ...   92   93   94   95   96   97   98   99
# x2   0   2   4   6   8  10  12  14  ...  184  186  188  190  192  194  196  198
#
# [2 rows x 100 columns]

# %%
plt.scatter(df4.loc['x1'], df4.loc['x2'])

# %%
# 3.Plot 모양 변형하기

# %%
# 비어있는 figure가 생성(도화지 만들기)
fig = plt.figure(figsize=(10,10))

# %%
# subplot 추가하기
# 여러개의 그래프를 그릴 수 있다.
# add_subplot 에는 총 3가지 인자가 들어간다.
ax1 = fig.add_subplot(2,1,1)     # 도화지의 구획을 나눈다.
ax2 = fig.add_subplot(2,1,2)     # 도화지의 구획을 나눈다.
ax1.scatter(df3['x1'], df3['x2'])  # 나뉜 구획에 그래프를 그린다.
ax2.scatter(df4['x1'], df4['x2'])  # 나뉜 구획에 그래프를 그린다.

# %%
fig

# %%
# 첫 번째 숫자와 두 번째 숫자 : 우리가 figure를 어떤 크기로 나눌지에 대한 값이다.
# (2, 2) 이면 figure를 2x2로 나눈다는 뜻이다.

# 세 번째 숫자 : 첫 번째, 두 번째 숫자로 나눈 figure에서
# 좌측 상단으로 우측 방향으로 숫자가 붙는다. 
# 이 때 add하고자 하는 subplot이 몇 번째에 들어가는지를 나타낸다.
# 즉, 위와 같은 경우 figure는 다음과 같이 나누어진다.
# 1 2
# 3 4
# 이 때 1위치에 subplot을 추가하고 해당 subplot을 ax1이라는 변수로 반환 받는다.

# %%
fig = plt.figure(figsize =(10,10))

ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

ax1.plot(df)
df2[['B','D']].plot(ax=ax2, kind='bar')
ax3.hist(s3)
ax4.scatter(df3.x1, df3.x2)

# %%
# 위치를 지정하지 않고 plot을 그리니 맨 마지막에 그림이 그려진다.
# figure에 추가된 subplot 상 맨 마지막에 위치한 곳에 그려지는 것이 아니라,
# 제일 마지막에 추가한 subplot에 그려진다.
# 2->3->1 순으로 subplot을 추가하여 테스트 해보면 1번 요소에 그려진다.

# %%
# 그럼 우리가 원하는 위치에 그림을 그리기 위해서는?
# 위에서 add_subplot 을 할 때 변수명을 지정하여 반환값을 받았다.
# 해당 변수를 통해 plot을 그리면 된다.

# %% [markdown]
# 컬러 종류
# <pre>
# 문자열	약자
# blue :	b
# green :	g
# red	: r
# cyan :	c
# magenta :	m
# yellow : y
# black :	k
# white :	w

# %% [markdown]
# 마커 종류
# <pre>
# 마커 문자열	의미
# .	point marker
# ,	pixel marker
# o	circle marker
# v	triangle_down marker
# ^	triangle_up marker
# <	triangle_left marker
# >	triangle_right marker
# 1	tri_down marker
# 2	tri_up marker
# 3	tri_left marker
# 4	tri_right marker
# s	square marker
# p	pentagon marker
# *	star marker
# h	hexagon1 marker
# H	hexagon2 marker
# +	plus marker
# x	x marker
# D	diamond marker
# d	thin_diamond marker

# %% [markdown]
# 선 종류
# <pre>
# 선 스타일 : 문자열	의미
# -	solid line style
# --	dashed line style
# -.	dash-dot line style
# :	dotted line style

# %%
# 3-1.plot 꾸미기
## 마커, 선 스타일 바꾸기

# %%
plt.plot(np.random.randn(50), color='g', marker='o', linestyle='--')

# %%
# 굳이 각각에 대해서 언급해주지 않고, 
# 아래와 같이 연속적으로 나타내줘도 된다.
plt.plot(np.random.randn(30), '.--k')

# %%
# 여러개를 그리는 또 다른 방법 적용
# plot 함수를 그릴 때, figure에서 원하는 위치를 지정하기 위해 ax 속성을 사용

fig, axes = plt.subplots(2, 1)

data = pd.Series(np.random.rand(16), index=list('abcdefghijklmnop'))

data.plot(kind='bar', ax=axes[0], color='k', alpha=0.7)

data.plot(kind='barh', ax=axes[1], color='g', alpha=0.3)

# %%
# 우리가 만들 plot의 눈금, 레이블, 범위 등을 지정 및 수정할 수 있다.

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(1,1,1)
ax.plot(np.random.randn(1000).cumsum())

# 이때 그래프에서 나타내는 눈금을 tick이라고 한다.
# 즉, 위의 그래프의 x tick은 200이고 y tick은 10이다.

ax.set_xticks([0, 250, 500, 750, 1000])

# 눈금을 문자로 하기 위해서는?

ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'], rotation = 30,
                           fontsize = 'medium')

# 제목 입력하기

ax.set_title('random walk plot')

# 라벨 입력하기

ax.set_xlabel('Stages')
ax.set_ylabel('Values')
# Out:
# Text(0, 0.5, 'Values')

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(1, 1, 1)

ax.plot(np.random.randn(1000).cumsum(), 'k', label='one')
ax.plot(np.random.randn(1000).cumsum(), 'b--', label='two')
ax.plot(np.random.randn(1000).cumsum(), 'r.', label='three')

# 범례 표시하기
ax.legend(loc='best')

# loc는 범례가 위치할 곳을 의미한다. best를 주게 되면 현재 그래프에서
# 최적의 위치를 자동으로 찾는다.

# x축의 범위 및 y축의 범위 수정하기
# 현재 그래프의 x축 범위를 가져온다.
ax.get_xlim()

# 이를 변경하려면,
ax.set_xlim([100,900])
# Out:
# (100, 900)

# %%
# 3.Matplotlib을 이용한 데이터시각화 맛보기
# 왕좌의 게임 소설/미드 내용 데이터셋
# battles : 실 작품에서의 battle/death 데이터를 포함
# deaths : 잠품에 등장하는 등장인물의 간단한 정보,
# 이들이 사망시 몇년도 어느 작품에서 사망했는지 등의 정보 포함
battles = pd.read_csv('battles.csv') # ,sep=','
deaths = pd.read_csv('character-deaths.csv')

# %% [markdown]
# Variables:
# <pre>
# name: String variable. The name of the battle.
# year: Numeric variable. The year of the battle.
# battle_number: Numeric variable. A unique ID number for the battle.
# attacker_king: Categorical. The attacker's king. A slash indicators that the king charges over the course of the war. For example, "Joffrey/Tommen Baratheon" is coded as such because one king follows the other in the Iron Throne.
# defender_king: Categorical variable. The defender's king.
# attacker_1: String variable. Major house attacking.
# attacker_2: String variable. Major house attacking.
# attacker_3: String variable. Major house attacking.
# attacker_4: String variable. Major house attacking.
# defender_1: String variable. Major house defending.
# defender_2: String variable. Major house defending.
# defender_3: String variable. Major house defending.
# defender_4: String variable. Major house defending.
# attacker_outcome: Categorical variable. The outcome from the perspective of the attacker. Categories: win, loss, draw.
# battle_type: Categorical variable. A classification of the battle's primary type. Categories:
# pitched_battle: Armies meet in a location and fight. This is also the baseline category.
# ambush: A battle where stealth or subterfuge was the primary means of attack.
# siege: A prolonged of a fortied position.
# razing: An attack against an undefended position
# major_death: Binary variable. If there was a death of a major figure during the battle.
# major_capture: Binary variable. If there was the capture of the major figure during the battle.
# attacker_size: Numeric variable. The size of the attacker's force. No distinction is made between the types of soldiers such as cavalry and footmen.
# defender_size: Numeric variable. The size of the defenders's force. No distinction is made between the types of soldiers such as cavalry and footmen.
# attacker_commander: String variable. Major commanders of the attackers. Commander's names are included without honoric titles and commandders are seperated by commas.
# defender_commander: String variable. Major commanders of the defener. Commander's names are included without honoric titles and commandders are seperated by commas.
# summer: Binary variable. Was it summer?
# location: String variable. The location of the battle.
# region: Categorical variable. The region where the battle takes place. Categories: Beyond the Wall, The North, The Iron Islands, The Riverlands, The Vale of Arryn, The Westerlands, The Crownlands, The Reach, The Stormlands, Dorne
# note: String variable. Coding notes regarding individual observations.

# %%
battles
# Out:
#                                                  name  ...                                               note
# 0                          Battle of the Golden Tooth  ...                                                NaN
# 1                         Battle at the Mummer's Ford  ...                                                NaN
# 2                                  Battle of Riverrun  ...                                                NaN
# 3                            Battle of the Green Fork  ...                                                NaN
# 4                       Battle of the Whispering Wood  ...                                                NaN
# 5                                 Battle of the Camps  ...                                                NaN
# 6                                       Sack of Darry  ...                                                NaN
# 7                               Battle of Moat Cailin  ...                                                NaN
# 8                            Battle of Deepwood Motte  ...                                                NaN
# 9                           Battle of the Stony Shore  ...  Greyjoy's troop number based on the Battle of ...
# 10                         Battle of Torrhen's Square  ...  Greyjoy's troop number comes from the 264 esti...
# 11                               Battle of Winterfell  ...  It isn't mentioned how many Stark men are left...
# 12                           Sack of Torrhen's Square  ...                                                NaN
# 13                                 Sack of Winterfell  ...  Since House Bolton betrays the Starks for Hous...
# 14                                  Battle of Oxcross  ...                                                NaN
# 15                               Siege of Storm's End  ...                                                NaN
# 16                                Battle of the Fords  ...                                                NaN
# 17                                  Sack of Harrenhal  ...                                                NaN
# 18                                 Battle of the Crag  ...                                                NaN
# 19                           Battle of the Blackwater  ...                                                NaN
# 20                                     Siege of Darry  ...                                                NaN
# 21                               Battle of Duskendale  ...                                                NaN
# 22                       Battle of the Burning Septry  ...                                                NaN
# 23                            Battle of the Ruby Ford  ...                                                NaN
# 24                              Retaking of Harrenhal  ...                                                NaN
# 25                                    The Red Wedding  ...  This observation refers to the battle against ...
# 26                                   Siege of Seagard  ...                                                NaN
# 27                             Battle of Castle Black  ...                                                NaN
# 28                                Fall of Moat Cailin  ...                                                NaN
# 29                                   Sack of Saltpans  ...                                                NaN
# 30                         Retaking of Deepwood Motte  ...                                                NaN
# 31                       Battle of the Shield Islands  ...                                                NaN
# 32  Invasion of Ryamsport, Vinetown, and Starfish ...  ...                                                NaN
# 33                        Second Seige of Storm's End  ...                                                NaN
# 34                               Siege of Dragonstone  ...                                                NaN
# 35                                  Siege of Riverrun  ...                                                NaN
# 36                                 Siege of Raventree  ...                                                NaN
# 37                                Siege of Winterfell  ...                                                NaN
#
# [38 rows x 25 columns]

# %%
battles.head()
# Out:
#                             name  year  ...           region note
# 0     Battle of the Golden Tooth   298  ...  The Westerlands  NaN
# 1    Battle at the Mummer's Ford   298  ...   The Riverlands  NaN
# 2             Battle of Riverrun   298  ...   The Riverlands  NaN
# 3       Battle of the Green Fork   298  ...   The Riverlands  NaN
# 4  Battle of the Whispering Wood   298  ...   The Riverlands  NaN
#
# [5 rows x 25 columns]

# %%
battles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 25 columns):
# name                  38 non-null object
# year                  38 non-null int64
# battle_number         38 non-null int64
# attacker_king         36 non-null object
# defender_king         35 non-null object
# attacker_1            38 non-null object
# attacker_2            10 non-null object
# attacker_3            3 non-null object
# attacker_4            2 non-null object
# defender_1            37 non-null object
# defender_2            2 non-null object
# defender_3            0 non-null float64
# defender_4            0 non-null float64
# attacker_outcome      37 non-null object
# battle_type           37 non-null object
# major_death           37 non-null float64
# major_capture         37 non-null float64
# attacker_size         24 non-null float64
# defender_size         19 non-null float64
# attacker_commander    37 non-null object
# defender_commander    28 non-null object
# summer                37 non-null float64
# location              37 non-null object
# region                38 non-null object
# note                  5 non-null object
# dtypes: float64(7), int64(2), object(16)
# memory usage: 7.5+ KB

# %%
battles.columns
# Out:
# Index(['name', 'year', 'battle_number', 'attacker_king', 'defender_king',
#        'attacker_1', 'attacker_2', 'attacker_3', 'attacker_4', 'defender_1',
#        'defender_2', 'defender_3', 'defender_4', 'attacker_outcome',
#        'battle_type', 'major_death', 'major_capture', 'attacker_size',
#        'defender_size', 'attacker_commander', 'defender_commander', 'summer',
#        'location', 'region', 'note'],
#       dtype='object')

# %%
battles.shape
# Out:
# (38, 25)

# %%
deaths.shape
# Out:
# (917, 13)

# %%
deaths.columns
# Out:
# Index(['Name', 'Allegiances', 'Death Year', 'Book of Death', 'Death Chapter',
#        'Book Intro Chapter', 'Gender', 'Nobility', 'GoT', 'CoK', 'SoS', 'FfC',
#        'DwD'],
#       dtype='object')

# %%
deaths.head()
# Out:
#                       Name      Allegiances  Death Year  ...  SoS  FfC  DwD
# 0           Addam Marbrand        Lannister         NaN  ...    1    1    0
# 1  Aegon Frey (Jinglebell)             None       299.0  ...    1    0    0
# 2          Aegon Targaryen  House Targaryen         NaN  ...    0    0    1
# 3            Adrack Humble    House Greyjoy       300.0  ...    0    0    1
# 4           Aemon Costayne        Lannister         NaN  ...    1    0    0
#
# [5 rows x 13 columns]

# %%
# 소설 기준으로 작품번호에 따른 인물들의 죽음 횟수 -> line plot으로.
# 작품별 사망한 인물의 총 수를 알 수 있음.
book_nums_to_death_count = deaths['Book of Death'].value_counts().sort_index()
book_nums_to_death_count
# Out:
# 1.0    49
# 2.0    73
# 3.0    97
# 4.0    27
# 5.0    61
# Name: Book of Death, dtype: int64

# %%
ax1 = book_nums_to_death_count.plot(color = 'k', marker='o', linestyle='--')

# %%
ax1 = book_nums_to_death_count.plot(color = 'k', marker='o', linestyle='--')

# 모양 가다듬기
ax1.set_xticks(np.arange(1,6))
# Out:
# [<matplotlib.axis.XTick at 0x7feaf56fb1d0>,
#  <matplotlib.axis.XTick at 0x7feaf56e14e0>,
#  <matplotlib.axis.XTick at 0x7feaf5686cc0>,
#  <matplotlib.axis.XTick at 0x7feaf5690358>,
#  <matplotlib.axis.XTick at 0x7feaf5690710>]

# %%
ax1 = book_nums_to_death_count.plot(color = 'k', marker='o', linestyle='--')

# 모양 가다듬기
ax1.set_xticks(np.arange(1,6))

# 그래프 축 범위 주기
ax1.set_xlim([0,6])
ax1.set_ylim([0,120])

# 3권에서 많이 죽었음을 확인 가능
# Out:
# (0, 120)

# %%
# battles 데이터셋에는 각 공격별로 공격군과 수비군에 대한 정보가 있음
# 공격군과 수비군의 병사수도 있음.
# attacker_size, defender_size
# 공격군과 수비군의 수가 1만명이 넘어가는 대규모 전투 상의 공/수군의 병력차이를 확인해보고
# box plot으로 시각화 해보자.

# %%
# 전투이름을 인덱스로 지정하기
battles = battles.set_index(['name'])
battles.head()
# Out:
#                                year  battle_number  ...           region note
# name                                                ...
# Battle of the Golden Tooth      298              1  ...  The Westerlands  NaN
# Battle at the Mummer's Ford     298              2  ...   The Riverlands  NaN
# Battle of Riverrun              298              3  ...   The Riverlands  NaN
# Battle of the Green Fork        298              4  ...   The Riverlands  NaN
# Battle of the Whispering Wood   298              5  ...   The Riverlands  NaN
#
# [5 rows x 24 columns]

# %%
# 전체 병력(공/수 합)이 1만명을 넘어가는 행 선택
# boolean mask 만들기
large_battle_mask = battles['attacker_size'] + battles['defender_size'] > 10000

# %%
# 이들의 병력 정보만 추출하여 변수에 담기
# large_battles 데이터프레임 만들기, 열은 attacker_size, defender_size를 가지게.
large_battles = battles.loc[large_battle_mask, ['attacker_size', 'defender_size']]

# %%
large_battles.shape
# Out:
# (10, 2)

# %%
large_battles
# Out:
#                             attacker_size  defender_size
# name
# Battle of the Golden Tooth        15000.0         4000.0
# Battle of Riverrun                15000.0        10000.0
# Battle of the Green Fork          18000.0        20000.0
# Battle of the Camps                6000.0        12625.0
# Battle of Oxcross                  6000.0        10000.0
# Siege of Storm's End               5000.0        20000.0
# Battle of the Fords               20000.0        10000.0
# Battle of the Blackwater          21000.0         7250.0
# Battle of Castle Black           100000.0         1240.0
# Siege of Winterfell                5000.0         8000.0

# %%
# 수평 barplot을 그리고 stacked옵션을 넣어줌.
# 10개의 대규모 전투에 대해 공/수 병력 차이를 나타내는 바플롯을 그림
ax2 = large_battles.plot(kind='barh', stacked=True, fontsize=8)

# %%
# 단일전투 하나하나의 공수 상대적 비율이 잘 들어나지 않았음.
# 각 전투에서의 병력의 상대적 비율을 알고자 함
# large_battles 데이터프레임에 새로운 컬럼 추가
# 공격군/공+수군 : 공격군의 비율
large_battles['attacker_pcts'] = large_battles['attacker_size']/(large_battles['attacker_size'] + large_battles['defender_size'])

# %%
# 수비군의 비율
large_battles['defender_pcts'] = large_battles['defender_size']/(large_battles['attacker_size']+large_battles['defender_size'])

# %%
large_battles
# Out:
#                             attacker_size  ...  defender_pcts
# name                                       ...
# Battle of the Golden Tooth        15000.0  ...       0.210526
# Battle of Riverrun                15000.0  ...       0.400000
# Battle of the Green Fork          18000.0  ...       0.526316
# Battle of the Camps                6000.0  ...       0.677852
# Battle of Oxcross                  6000.0  ...       0.625000
# Siege of Storm's End               5000.0  ...       0.800000
# Battle of the Fords               20000.0  ...       0.333333
# Battle of the Blackwater          21000.0  ...       0.256637
# Battle of Castle Black           100000.0  ...       0.012248
# Siege of Winterfell                5000.0  ...       0.615385
#
# [10 rows x 4 columns]

# %%
# 두개 열로 바플롯 그리기
# 각 전투 별 공수군 간의 병력차이가 확연히 드러나게 보일 수 있다.
ax3 = large_battles[['attacker_pcts', 'defender_pcts']].plot(kind='barh', stacked=True, fontsize=8)
